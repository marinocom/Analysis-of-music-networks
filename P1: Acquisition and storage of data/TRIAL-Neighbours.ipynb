# %%
import networkx as nx
import pandas as pd
import spotipy
from spotipy . oauth2 import SpotifyClientCredentials


# Marino Oliveros Blanco NIU:1668563
# Pere Mayol Carbonell NIU:1669503


# ------- AUXILIARY FUNCTIONS ------- #
def degree_statistics(graph):
    in_degrees = [d for n, d in graph.in_degree()]
    out_degrees = [d for n, d in graph.out_degree()]
    
    stats = {
        "in_degree": {
            "min": min(in_degrees),
            "max": max(in_degrees),
            "median": sorted(in_degrees)[len(in_degrees)//2]
        },
        "out_degree": {
            "min": min(out_degrees),
            "max": max(out_degrees),
            "median": sorted(out_degrees)[len(out_degrees)//2]
        },
        "number_of_nodes": graph.number_of_nodes(),
        "number_of_edges": graph.number_of_edges()
    }
    return stats
# --------------- END OF AUXILIARY FUNCTIONS ------------------ #

# %%
def search_artist(sp: spotipy.client.Spotify, artist_name: str) -> str:
    """
    Search for an artist in Spotify.

    :param sp: spotipy client object
    :param artist_name: name to search for.
    :return: spotify artist id.
    """

    id = sp.search(artist_name, type='artist', limit=5)['artists']['items'][0]['id'] # Get the first result

    return id

# %%
def crawler(sp: spotipy.client.Spotify, seed: str, max_nodes_to_crawl: int, strategy: str = "BFS", 
            out_filename: str = "g.graphml") -> nx.DiGraph:
    """
    Crawl the Spotify artist graph, following related artists.

    :param sp: spotipy client object
    :param seed: starting artist id.
    :param max_nodes_to_crawl: maximum number of nodes to crawl.
    :param strategy: BFS or DFS.
    :param out_filename: name of the graphml output file.
    :return: networkx directed graph.
    """

    G = nx.DiGraph()
    visited = set()
    all_related_artists = set()
    api_call_count = 0  # Initialize the API call counter

    if strategy == "BFS":
        queue = [(seed, None)]  # BFS uses a queue
    else:
        stack = [(seed, None)]  # DFS uses a stack

    while len(visited) < max_nodes_to_crawl:
        if strategy == "BFS" and queue:
            current_artist_id, parent_id = queue.pop(0)
        elif strategy == "DFS" and stack:
            current_artist_id, parent_id = stack.pop()
        else:
            break

        if current_artist_id not in visited:
            visited.add(current_artist_id)
            try:
                artist_info = sp.artist(current_artist_id)
                api_call_count += 1  # Increment the API call counter
                print(f"API call {api_call_count}: Retrieved artist {current_artist_id}")
                G.add_node(current_artist_id, 
                           name=artist_info['name'],
                           followers=artist_info['followers']['total'],
                           popularity=artist_info['popularity'],
                           genres=";".join(artist_info['genres']))  # Convert list to string
                if parent_id:
                    G.add_edge(parent_id, current_artist_id)

                related_artists = sp.artist_related_artists(current_artist_id)['artists']
                api_call_count += 1  # Increment the API call counter
                print(f"API call {api_call_count}: Retrieved related artists for {current_artist_id}")
                for related_artist in related_artists:
                    if related_artist['id'] not in visited:
                        G.add_node(related_artist['id'],
                                   name=related_artist['name'],
                                   followers=related_artist['followers']['total'],
                                   popularity=related_artist['popularity'],
                                   genres=";".join(related_artist['genres']))
                    all_related_artists.add((current_artist_id, related_artist['id']))
                    if strategy == "BFS":
                        queue.append((related_artist['id'], current_artist_id))
                    else:
                        stack.append((related_artist['id'], current_artist_id))
            except Exception as e:
                print(f"Error processing artist {current_artist_id}: {e}")
                continue

    # Add edges for all related artists
    for parent_id, related_artist_id in all_related_artists:
        if parent_id in G and related_artist_id in G:
            G.add_edge(parent_id, related_artist_id)

    nx.write_graphml(G, out_filename)
    
    print(f"Total API calls made: {api_call_count}")  # Print the total number of API calls made
    return G

# %%
import time
import pandas as pd
import networkx as nx
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

def get_track_data(sp, graph, output_file, batch_size=26, delay=10):
    """
    Get track data for each visited artist in the graph in batches to avoid rate limiting.

    :param sp: spotipy client object
    :param graph: graph with artists as nodes.
    :param output_file: name of the csv output file.
    :param batch_size: number of artists to process in each batch.
    :param delay: delay between batches in seconds.
    :return: pandas dataframe with track data.
    """
    tracks = []
    max_retries = 5

    # Helper function to handle retries and rate limits
    def fetch_with_retries(func, *args, **kwargs):
        retries = 0
        while retries < max_retries:
            try:
                return func(*args, **kwargs)
            except spotipy.exceptions.SpotifyException as e:
                if e.http_status == 429:
                    retry_after = int(e.headers.get('Retry-After', delay))
                    print(f"Rate limit exceeded. Retrying after {retry_after} seconds.")
                    time.sleep(retry_after)
                else:
                    retries += 1
                    print(f"Retrying ({retries}/{max_retries}) due to error: {e}")
                    time.sleep(5)  # Wait for 5 seconds before retrying
            except Exception as e:
                retries += 1
                print(f"Retrying ({retries}/{max_retries}) due to error: {e}")
                time.sleep(5)  # Wait for 5 seconds before retrying
        return None

    all_artist_ids = [node for node in graph.nodes]

    for i in range(0, len(all_artist_ids), batch_size):
        batch_artist_ids = all_artist_ids[i:i+batch_size]

        for artist_id in batch_artist_ids:
            results = fetch_with_retries(sp.artist_top_tracks, artist_id)
            if results is None:
                continue

            for track in results['tracks']:
                # Fetch audio features
                audio_features = fetch_with_retries(sp.audio_features, track['id'])
                if not audio_features or not audio_features[0]:
                    continue
                audio_features = audio_features[0]

                tracks.append({
                    'artist_id': artist_id,
                    'artist_name': track['artists'][0]['name'],
                    'track_id': track['id'],
                    'track_name': track['name'],
                    'track_duration': track['duration_ms'],
                    'track_popularity': track['popularity'],
                    'danceability': audio_features['danceability'],
                    'energy': audio_features['energy'],
                    'loudness': audio_features['loudness'],
                    'speechiness': audio_features['speechiness'],
                    'acousticness': audio_features['acousticness'],
                    'instrumentalness': audio_features['instrumentalness'],
                    'liveness': audio_features['liveness'],
                    'valence': audio_features['valence'],
                    'tempo': audio_features['tempo'],
                    'album_id': track['album']['id'],
                    'album_name': track['album']['name'],
                    'album_release_date': track['album']['release_date']
                })

        # Wait for the specified delay before processing the next batch
        if i + batch_size < len(all_artist_ids):
            print(f"Batch {i // batch_size + 1} processed. Waiting for {delay} seconds...")
            time.sleep(delay)

    # Save the data to a csv file so we can correctly output the songs.csv
    df = pd.DataFrame(tracks)
    df.to_csv(output_file, index=False)

    return df

# %%
if __name__ == "__main__":

    CLIENT_ID = "a96a3af9660440769efb49b1785fd7b2"
    CLIENT_SECRET = "2e50c0969ed44cd0a254ad301de00f50"



    auth_manager = SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET
    )

    sp = spotipy.Spotify(auth_manager=auth_manager)

    id1 = search_artist(sp, "Taylor Swift")
    print("Taylor Swift id:", id1)

    Gb = crawler(sp, id1, 100, strategy='BFS', out_filename="gB.graphml") # 100 nodes/artists
    stats_gb = degree_statistics(Gb)
    print("Taylor Swift crawled BFS")
    print(f"gB degree stats: {stats_gb}")
    

    Gd = crawler(sp, id1, 100, strategy='DFS', out_filename="gD.graphml")
    print("Taylor Swift crawled DFS")
    stats_gd = degree_statistics(Gd)
    print(f"gD degree stats: {stats_gd}")

    id2 = search_artist(sp, "Pastel Ghost")
    print("Taylor Swift id:", id1)

    Hb = crawler(sp, id2, 100, strategy='BFS', out_filename="hB.graphml")
    print("Pastel Ghost crawled BFS")
    print(f"hB degree stats: {degree_statistics(Hb)}")
# Out:
# Taylor Swift id: 06HL4z0CvFAxyc27GXpf02
# API call 1: Retrieved artist 06HL4z0CvFAxyc27GXpf02
# API call 2: Retrieved related artists for 06HL4z0CvFAxyc27GXpf02
# API call 3: Retrieved artist 0C8ZW7ezQVs4URX5aX7Kqx
# API call 4: Retrieved related artists for 0C8ZW7ezQVs4URX5aX7Kqx
# API call 5: Retrieved artist 1McMsnEElThX1knmY4oliG
# API call 6: Retrieved related artists for 1McMsnEElThX1knmY4oliG
# API call 7: Retrieved artist 6jJ0s89eD6GaHleKKya26X
# API call 8: Retrieved related artists for 6jJ0s89eD6GaHleKKya26X
# API call 9: Retrieved artist 66CXWjxzNUsdJxJ2JdwvnR
# API call 10: Retrieved related artists for 66CXWjxzNUsdJxJ2JdwvnR
# API call 11: Retrieved artist 6KImCVD70vtIoJWnq6nGn3
# API call 12: Retrieved related artists for 6KImCVD70vtIoJWnq6nGn3
# API call 13: Retrieved artist 4nDoRrQiYLoBzwC5BhVJzF
# API call 14: Retrieved related artists for 4nDoRrQiYLoBzwC5BhVJzF
# API call 15: Retrieved artist 4AK6F7OLvEQ5QYCBNiQWHq
# API call 16: Retrieved related artists for 4AK6F7OLvEQ5QYCBNiQWHq
# API call 17: Retrieved artist 6S2OmqARrzebs0tKUEyXyp
# API call 18: Retrieved related artists for 6S2OmqARrzebs0tKUEyXyp
# API call 19: Retrieved artist 6JL8zeS1NmiOftqZTRgdTz
# API call 20: Retrieved related artists for 6JL8zeS1NmiOftqZTRgdTz
# API call 21: Retrieved artist 74KM79TiuVKeVCqs8QtB0B
# API call 22: Retrieved related artists for 74KM79TiuVKeVCqs8QtB0B
# API call 23: Retrieved artist 5YGY8feqx7naU7z4HrwZM6
# API call 24: Retrieved related artists for 5YGY8feqx7naU7z4HrwZM6
# API call 25: Retrieved artist 7n2wHs1TKAczGzO7Dd2rGr
# API call 26: Retrieved related artists for 7n2wHs1TKAczGzO7Dd2rGr
# API call 27: Retrieved artist 6M2wZ9GZgrQXHCFfjv46we
# API call 28: Retrieved related artists for 6M2wZ9GZgrQXHCFfjv46we
# API call 29: Retrieved artist 1uNFoZAHBGtllmzznpCI3s
# API call 30: Retrieved related artists for 1uNFoZAHBGtllmzznpCI3s
# API call 31: Retrieved artist 00FQb4jTyendYWaN8pK0wa
# API call 32: Retrieved related artists for 00FQb4jTyendYWaN8pK0wa
# API call 33: Retrieved artist 26VFTg2z8YR0cCuwLzESi2
# API call 34: Retrieved related artists for 26VFTg2z8YR0cCuwLzESi2
# API call 35: Retrieved artist 6qqNVTkY8uBg9cP3Jd7DAH
# API call 36: Retrieved related artists for 6qqNVTkY8uBg9cP3Jd7DAH
# API call 37: Retrieved artist 6VuMaDnrHyPL1p4EHjYLi7
# API call 38: Retrieved related artists for 6VuMaDnrHyPL1p4EHjYLi7
# API call 39: Retrieved artist 5ZsFI1h6hIdQRw2ti0hz81
# API call 40: Retrieved related artists for 5ZsFI1h6hIdQRw2ti0hz81
# API call 41: Retrieved artist 4Uc8Dsxct0oMqx0P6i60ea
# API call 42: Retrieved related artists for 4Uc8Dsxct0oMqx0P6i60ea
# API call 43: Retrieved artist 6dJeKm76NjfXBNTpHmOhfO
# API call 44: Retrieved related artists for 6dJeKm76NjfXBNTpHmOhfO
# API call 45: Retrieved artist 1l8Fu6IkuTP0U5QetQJ5Xt
# API call 46: Retrieved related artists for 1l8Fu6IkuTP0U5QetQJ5Xt
# API call 47: Retrieved artist 4Rxn7Im3LGfyRkY2FlHhWi
# API call 48: Retrieved related artists for 4Rxn7Im3LGfyRkY2FlHhWi
# API call 49: Retrieved artist 64M6ah0SkkRsnPGtGiRAbb
# API call 50: Retrieved related artists for 64M6ah0SkkRsnPGtGiRAbb
# API call 51: Retrieved artist 1zNqDE7qDGCsyzJwohVaoX
# API call 52: Retrieved related artists for 1zNqDE7qDGCsyzJwohVaoX
# API call 53: Retrieved artist 3e7awlrlDSwF3iM0WBjGMp
# API call 54: Retrieved related artists for 3e7awlrlDSwF3iM0WBjGMp
# API call 55: Retrieved artist 1Xylc3o4UrD53lo9CvFvVg
# API call 56: Retrieved related artists for 1Xylc3o4UrD53lo9CvFvVg
# API call 57: Retrieved artist 5p7f24Rk5HkUZsaS3BLG5F
# API call 58: Retrieved related artists for 5p7f24Rk5HkUZsaS3BLG5F
# API call 59: Retrieved artist 2wUjUUtkb5lvLKcGKsKqsR
# API call 60: Retrieved related artists for 2wUjUUtkb5lvLKcGKsKqsR
# API call 61: Retrieved artist 6sCbFbEjbYepqswM1vWjjs
# API call 62: Retrieved related artists for 6sCbFbEjbYepqswM1vWjjs
# API call 63: Retrieved artist 45dkTj5sMRSjrmBSBeiHym
# API call 64: Retrieved related artists for 45dkTj5sMRSjrmBSBeiHym
# API call 65: Retrieved artist 2kRfqPViCqYdSGhYSM9R0Q
# API call 66: Retrieved related artists for 2kRfqPViCqYdSGhYSM9R0Q
# API call 67: Retrieved artist 5cj0lLjcoR7YOSnhnX0Po5
# API call 68: Retrieved related artists for 5cj0lLjcoR7YOSnhnX0Po5
# API call 69: Retrieved artist 4tuJ0bMpJh08umKkEXKUI5
# API call 70: Retrieved related artists for 4tuJ0bMpJh08umKkEXKUI5
# API call 71: Retrieved artist 2W8yFh0Ga6Yf3jiayVxwkE
# API call 72: Retrieved related artists for 2W8yFh0Ga6Yf3jiayVxwkE
# API call 73: Retrieved artist 63yrD80RY3RNEM2YDpUpO8
# API call 74: Retrieved related artists for 63yrD80RY3RNEM2YDpUpO8
# API call 75: Retrieved artist 4VdV2qRAYBLINR6uU72V1J
# API call 76: Retrieved related artists for 4VdV2qRAYBLINR6uU72V1J
# API call 77: Retrieved artist 7tYKF4w9nC0nq9CsPZTHyP
# API call 78: Retrieved related artists for 7tYKF4w9nC0nq9CsPZTHyP
# API call 79: Retrieved artist 3uwAm6vQy7kWPS2bciKWx9
# API call 80: Retrieved related artists for 3uwAm6vQy7kWPS2bciKWx9
# API call 81: Retrieved artist 26dSoYclwsYLMAKD3tpOr4
# API call 82: Retrieved related artists for 26dSoYclwsYLMAKD3tpOr4
# API call 83: Retrieved artist 1HY2Jd0NmPuamShAr6KMms
# API call 84: Retrieved related artists for 1HY2Jd0NmPuamShAr6KMms
# API call 85: Retrieved artist 6LqNN22kT3074XbTVUrhzX
# API call 86: Retrieved related artists for 6LqNN22kT3074XbTVUrhzX
# API call 87: Retrieved artist 0p4nmQO2msCgU4IF37Wi3j
# API call 88: Retrieved related artists for 0p4nmQO2msCgU4IF37Wi3j
# API call 89: Retrieved artist 2gsggkzM5R49q6jpPvazou
# API call 90: Retrieved related artists for 2gsggkzM5R49q6jpPvazou
# API call 91: Retrieved artist 3BmGtnKgCSGYIUhmivXKWX
# API call 92: Retrieved related artists for 3BmGtnKgCSGYIUhmivXKWX
# API call 93: Retrieved artist 1l7ZsJRRS8wlW3WfJfPfNS
# API call 94: Retrieved related artists for 1l7ZsJRRS8wlW3WfJfPfNS
# API call 95: Retrieved artist 0X2BH1fck6amBIoJhDVmmJ
# API call 96: Retrieved related artists for 0X2BH1fck6amBIoJhDVmmJ
# API call 97: Retrieved artist 1KCSPY1glIKqW2TotWuXOR
# API call 98: Retrieved related artists for 1KCSPY1glIKqW2TotWuXOR
# API call 99: Retrieved artist 5WUlDfRSoLAfcVSX1WnrxN
# API call 100: Retrieved related artists for 5WUlDfRSoLAfcVSX1WnrxN
# API call 101: Retrieved artist 0hCNtLu0JehylgoiP8L4Gh
# API call 102: Retrieved related artists for 0hCNtLu0JehylgoiP8L4Gh
# API call 103: Retrieved artist 4kYSro6naA4h99UJvo89HB
# API call 104: Retrieved related artists for 4kYSro6naA4h99UJvo89HB
# API call 105: Retrieved artist 5pKCCKE2ajJHZ9KAiaK11H
# API call 106: Retrieved related artists for 5pKCCKE2ajJHZ9KAiaK11H
# API call 107: Retrieved artist 57WHJIHrjOE3iAxpihhMnp
# API call 108: Retrieved related artists for 57WHJIHrjOE3iAxpihhMnp
# API call 109: Retrieved artist 1Hsdzj7Dlq2I7tHP7501T4
# API call 110: Retrieved related artists for 1Hsdzj7Dlq2I7tHP7501T4
# API call 111: Retrieved artist 5pUo3fmmHT8bhCyHE52hA6
# API call 112: Retrieved related artists for 5pUo3fmmHT8bhCyHE52hA6
# API call 113: Retrieved artist 5Rl15oVamLq7FbSb0NNBNy
# API call 114: Retrieved related artists for 5Rl15oVamLq7FbSb0NNBNy
# API call 115: Retrieved artist 7gOdHgIoIKoe4i9Tta6qdD
# API call 116: Retrieved related artists for 7gOdHgIoIKoe4i9Tta6qdD
# API call 117: Retrieved artist 3WGpXCj9YhhfX11TToZcXP
# API call 118: Retrieved related artists for 3WGpXCj9YhhfX11TToZcXP
# API call 119: Retrieved artist 7gAppWoH7pcYmphCVTXkzs
# API call 120: Retrieved related artists for 7gAppWoH7pcYmphCVTXkzs
# API call 121: Retrieved artist 5CCwRZC6euC8Odo6y9X8jr
# API call 122: Retrieved related artists for 5CCwRZC6euC8Odo6y9X8jr
# API call 123: Retrieved artist 4npEfmQ6YuiwW1GpUmaq3F
# API call 124: Retrieved related artists for 4npEfmQ6YuiwW1GpUmaq3F
# API call 125: Retrieved artist 4IWBUUAFIplrNtaOHcJPRM
# API call 126: Retrieved related artists for 4IWBUUAFIplrNtaOHcJPRM
# API call 127: Retrieved artist 7nU4hB040gTmHm45YYMvqc
# API call 128: Retrieved related artists for 7nU4hB040gTmHm45YYMvqc
# API call 129: Retrieved artist 5yG7ZAZafVaAlMTeBybKAL
# API call 130: Retrieved related artists for 5yG7ZAZafVaAlMTeBybKAL
# API call 131: Retrieved artist 7bp2lSdh12wcA8LyB1srfJ
# API call 132: Retrieved related artists for 7bp2lSdh12wcA8LyB1srfJ
# API call 133: Retrieved artist 2hUYKu1x0UZQXvzCmggvSn
# API call 134: Retrieved related artists for 2hUYKu1x0UZQXvzCmggvSn
# API call 135: Retrieved artist 4UxLFBvSr4xMDpHe1lrLrH
# API call 136: Retrieved related artists for 4UxLFBvSr4xMDpHe1lrLrH
# API call 137: Retrieved artist 7pwufEBGfggjoI8twqlsmQ
# API call 138: Retrieved related artists for 7pwufEBGfggjoI8twqlsmQ
# API call 139: Retrieved artist 188VINPQh5dyNfLUkevKqf
# API call 140: Retrieved related artists for 188VINPQh5dyNfLUkevKqf
# API call 141: Retrieved artist 2DlGxzQSjYe5N6G9nkYghR
# API call 142: Retrieved related artists for 2DlGxzQSjYe5N6G9nkYghR
# API call 143: Retrieved artist 6MDME20pz9RveH9rEXvrOM
# API call 144: Retrieved related artists for 6MDME20pz9RveH9rEXvrOM
# API call 145: Retrieved artist 7vk5e3vY1uw9plTHJAMwjN
# API call 146: Retrieved related artists for 7vk5e3vY1uw9plTHJAMwjN
# API call 147: Retrieved artist 6eUKZXaKkcviH0Ku9w2n3V
# API call 148: Retrieved related artists for 6eUKZXaKkcviH0Ku9w2n3V
# API call 149: Retrieved artist 04gDigrS5kc9YWfZHwBETP
# API call 150: Retrieved related artists for 04gDigrS5kc9YWfZHwBETP
# API call 151: Retrieved artist 77SW9BnxLY8rJ0RciFqkHh
# API call 152: Retrieved related artists for 77SW9BnxLY8rJ0RciFqkHh
# API call 153: Retrieved artist 2uYWxilOVlUdk4oV9DvwqK
# API call 154: Retrieved related artists for 2uYWxilOVlUdk4oV9DvwqK
# API call 155: Retrieved artist 1QAJqy2dA3ihHBFIHRphZj
# API call 156: Retrieved related artists for 1QAJqy2dA3ihHBFIHRphZj
# API call 157: Retrieved artist 0Y6dVaC9DZtPNH4591M42W
# API call 158: Retrieved related artists for 0Y6dVaC9DZtPNH4591M42W
# API call 159: Retrieved artist 7Ln80lUS6He07XvHI8qqHH
# API call 160: Retrieved related artists for 7Ln80lUS6He07XvHI8qqHH
# API call 161: Retrieved artist 6CwfuxIqcltXDGjfZsMd9A
# API call 162: Retrieved related artists for 6CwfuxIqcltXDGjfZsMd9A
# API call 163: Retrieved artist 7cYEt1pqMgXJdq00hAwVpT
# API call 164: Retrieved related artists for 7cYEt1pqMgXJdq00hAwVpT
# API call 165: Retrieved artist 1U1el3k54VvEUzo3ybLPlM
# API call 166: Retrieved related artists for 1U1el3k54VvEUzo3ybLPlM
# API call 167: Retrieved artist 3l0CmX0FuQjFxr8SK7Vqag
# API call 168: Retrieved related artists for 3l0CmX0FuQjFxr8SK7Vqag
# API call 169: Retrieved artist 163tK9Wjr9P9DmM0AVK7lm
# API call 170: Retrieved related artists for 163tK9Wjr9P9DmM0AVK7lm
# API call 171: Retrieved artist 35l9BRT7MXmM8bv2WDQiyB
# API call 172: Retrieved related artists for 35l9BRT7MXmM8bv2WDQiyB
# API call 173: Retrieved artist 3Sz7ZnJQBIHsXLUSo0OQtM
# API call 174: Retrieved related artists for 3Sz7ZnJQBIHsXLUSo0OQtM
# API call 175: Retrieved artist 3yY2gUcIsjMr8hjo51PoJ8
# API call 176: Retrieved related artists for 3yY2gUcIsjMr8hjo51PoJ8
# API call 177: Retrieved artist 0ZED1XzwlLHW4ZaG4lOT6m
# API call 178: Retrieved related artists for 0ZED1XzwlLHW4ZaG4lOT6m
# API call 179: Retrieved artist 4NHQUGzhtTLFvgF5SZesLK
# API call 180: Retrieved related artists for 4NHQUGzhtTLFvgF5SZesLK
# API call 181: Retrieved artist 3LjhVl7GzYsza1biQjTpaN
# API call 182: Retrieved related artists for 3LjhVl7GzYsza1biQjTpaN
# API call 183: Retrieved artist 1o2NpYGqHiCq7FoiYdyd1x
# API call 184: Retrieved related artists for 1o2NpYGqHiCq7FoiYdyd1x
# API call 185: Retrieved artist 1Xyo4u8uXC1ZmMpatF05PJ
# API call 186: Retrieved related artists for 1Xyo4u8uXC1ZmMpatF05PJ
# API call 187: Retrieved artist 4dpARuHxo51G3z768sgnrY
# API call 188: Retrieved related artists for 4dpARuHxo51G3z768sgnrY
# API call 189: Retrieved artist 2wY79sveU1sp5g7SokKOiI
# API call 190: Retrieved related artists for 2wY79sveU1sp5g7SokKOiI
# API call 191: Retrieved artist 69GGBxA162lTqCwzJG5jLp
# API call 192: Retrieved related artists for 69GGBxA162lTqCwzJG5jLp
# API call 193: Retrieved artist 5JZ7CnR6gTvEMKX4g70Amv
# API call 194: Retrieved related artists for 5JZ7CnR6gTvEMKX4g70Amv
# API call 195: Retrieved artist 4GvEc3ANtPPjt1ZJllr5Zl
# API call 196: Retrieved related artists for 4GvEc3ANtPPjt1ZJllr5Zl
# API call 197: Retrieved artist 0ZUvK7zGdXLd78mQr3t1Tw
# API call 198: Retrieved related artists for 0ZUvK7zGdXLd78mQr3t1Tw
# API call 199: Retrieved artist 2hR4h1Cao2ueuI7Cx9c7V8
# API call 200: Retrieved related artists for 2hR4h1Cao2ueuI7Cx9c7V8
# Total API calls made: 200
# Taylor Swift crawled BFS
# gB degree stats: {'in_degree': {'min': 1, 'max': 38, 'median': 2}, 'out_degree': {'min': 0, 'max': 20, 'median': 0}, 'number_of_nodes': 473, 'number_of_edges': 2000}
# API call 1: Retrieved artist 06HL4z0CvFAxyc27GXpf02
# API call 2: Retrieved related artists for 06HL4z0CvFAxyc27GXpf02
# API call 3: Retrieved artist 4Uc8Dsxct0oMqx0P6i60ea
# API call 4: Retrieved related artists for 4Uc8Dsxct0oMqx0P6i60ea
# API call 5: Retrieved artist 3WGpXCj9YhhfX11TToZcXP
# API call 6: Retrieved related artists for 3WGpXCj9YhhfX11TToZcXP
# API call 7: Retrieved artist 5p7f24Rk5HkUZsaS3BLG5F
# API call 8: Retrieved related artists for 5p7f24Rk5HkUZsaS3BLG5F
# API call 9: Retrieved artist 5pUo3fmmHT8bhCyHE52hA6
# API call 10: Retrieved related artists for 5pUo3fmmHT8bhCyHE52hA6
# API call 11: Retrieved artist 2jnIB6XdLvnJUeNTy5A0J2
# API call 12: Retrieved related artists for 2jnIB6XdLvnJUeNTy5A0J2
# API call 13: Retrieved artist 1Hsdzj7Dlq2I7tHP7501T4
# API call 14: Retrieved related artists for 1Hsdzj7Dlq2I7tHP7501T4
# API call 15: Retrieved artist 3zOKGDS77tYdGFQ6UJMC4E
# API call 16: Retrieved related artists for 3zOKGDS77tYdGFQ6UJMC4E
# API call 17: Retrieved artist 4UxLFBvSr4xMDpHe1lrLrH
# API call 18: Retrieved related artists for 4UxLFBvSr4xMDpHe1lrLrH
# API call 19: Retrieved artist 2Zi3RrdQqk63Xj0914STkS
# API call 20: Retrieved related artists for 2Zi3RrdQqk63Xj0914STkS
# API call 21: Retrieved artist 58AqJv0sDFPFnnBcLT8eeX
# API call 22: Retrieved related artists for 58AqJv0sDFPFnnBcLT8eeX
# API call 23: Retrieved artist 116v5BJngSpJcXNml0OPeu
# API call 24: Retrieved related artists for 116v5BJngSpJcXNml0OPeu
# API call 25: Retrieved artist 1KYszkVzlhV3rAqmAcYIgd
# API call 26: Retrieved related artists for 1KYszkVzlhV3rAqmAcYIgd
# API call 27: Retrieved artist 7rPQ2z1ji1ctJ6oGYBAo6M
# API call 28: Retrieved related artists for 7rPQ2z1ji1ctJ6oGYBAo6M
# API call 29: Retrieved artist 6oW9KRAZbC1xOlmg2RRyFL
# API call 30: Retrieved related artists for 6oW9KRAZbC1xOlmg2RRyFL
# API call 31: Retrieved artist 4mxl5fw4lcN4nSg8XadDKX
# API call 32: Retrieved related artists for 4mxl5fw4lcN4nSg8XadDKX
# API call 33: Retrieved artist 2uTXJwJ1Q9PA2ji51RWeQm
# API call 34: Retrieved related artists for 2uTXJwJ1Q9PA2ji51RWeQm
# API call 35: Retrieved artist 6iOvIzJzeDKmXWrUlchtKz
# API call 36: Retrieved related artists for 6iOvIzJzeDKmXWrUlchtKz
# API call 37: Retrieved artist 20EGKg0XsxPJ0GRHxfb9LX
# API call 38: Retrieved related artists for 20EGKg0XsxPJ0GRHxfb9LX
# API call 39: Retrieved artist 3ggXjUaLzPuY775WFABpXe
# API call 40: Retrieved related artists for 3ggXjUaLzPuY775WFABpXe
# API call 41: Retrieved artist 1A0Jf1TgQQUoWAoXFWhlQf
# API call 42: Retrieved related artists for 1A0Jf1TgQQUoWAoXFWhlQf
# API call 43: Retrieved artist 1YWJ1WjMkBCB1X3QOJ1Wdn
# API call 44: Retrieved related artists for 1YWJ1WjMkBCB1X3QOJ1Wdn
# API call 45: Retrieved artist 1tFnKlJuDU1PvvvkEx9mi7
# API call 46: Retrieved related artists for 1tFnKlJuDU1PvvvkEx9mi7
# API call 47: Retrieved artist 4xIK3OdlUfc3EH1gIG8Slr
# API call 48: Retrieved related artists for 4xIK3OdlUfc3EH1gIG8Slr
# API call 49: Retrieved artist 1c9HvyZemDcNy18QrNFeTN
# API call 50: Retrieved related artists for 1c9HvyZemDcNy18QrNFeTN
# API call 51: Retrieved artist 0mZsmXegjYM7hNw0QGE5b7
# API call 52: Retrieved related artists for 0mZsmXegjYM7hNw0QGE5b7
# API call 53: Retrieved artist 5Hp5hfBF49kKn8KAkgvNhz
# API call 54: Retrieved related artists for 5Hp5hfBF49kKn8KAkgvNhz
# API call 55: Retrieved artist 6sa5JC8xdrw2ZpGQ50nVCW
# API call 56: Retrieved related artists for 6sa5JC8xdrw2ZpGQ50nVCW
# API call 57: Retrieved artist 6dn6x1XOng3LOAnfTjUn77
# API call 58: Retrieved related artists for 6dn6x1XOng3LOAnfTjUn77
# API call 59: Retrieved artist 4HLVASaI7mpSxzIGZSRJVa
# API call 60: Retrieved related artists for 4HLVASaI7mpSxzIGZSRJVa
# API call 61: Retrieved artist 0danUECyxAcVygY4daqBGt
# API call 62: Retrieved related artists for 0danUECyxAcVygY4daqBGt
# API call 63: Retrieved artist 5fdok8zKLIq2P82BqLIhZ5
# API call 64: Retrieved related artists for 5fdok8zKLIq2P82BqLIhZ5
# API call 65: Retrieved artist 5FB4B4AT40XRVEEaGvjDAP
# API call 66: Retrieved related artists for 5FB4B4AT40XRVEEaGvjDAP
# API call 67: Retrieved artist 0AcQzV75nMVCmChGNyGzPH
# API call 68: Retrieved related artists for 0AcQzV75nMVCmChGNyGzPH
# API call 69: Retrieved artist 7LgMETw5wUxCOnKwxkN3l6
# API call 70: Retrieved related artists for 7LgMETw5wUxCOnKwxkN3l6
# API call 71: Retrieved artist 1foCMRbxVRo99EWPglSD3n
# API call 72: Retrieved related artists for 1foCMRbxVRo99EWPglSD3n
# API call 73: Retrieved artist 4opG4daBqDC4UOGwQbweRn
# API call 74: Retrieved related artists for 4opG4daBqDC4UOGwQbweRn
# API call 75: Retrieved artist 2BmSsK3ZETxNVex0u5SrMc
# API call 76: Retrieved related artists for 2BmSsK3ZETxNVex0u5SrMc
# API call 77: Retrieved artist 2o8QOahkX36KsjBt16vEOE
# API call 78: Retrieved related artists for 2o8QOahkX36KsjBt16vEOE
# API call 79: Retrieved artist 2mjqT7Yg4BYLmbzJJn0xb8
# API call 80: Retrieved related artists for 2mjqT7Yg4BYLmbzJJn0xb8
# API call 81: Retrieved artist 53pWXyjnYx2aXzUWZPDVpf
# API call 82: Retrieved related artists for 53pWXyjnYx2aXzUWZPDVpf
# API call 83: Retrieved artist 0GbXJUvZZUNGpN7aux6luK
# API call 84: Retrieved related artists for 0GbXJUvZZUNGpN7aux6luK
# API call 85: Retrieved artist 0qzkE4Zz56jh5s2szlGvsm
# API call 86: Retrieved related artists for 0qzkE4Zz56jh5s2szlGvsm
# API call 87: Retrieved artist 0G96TkItgnb79cFLnUbdhy
# API call 88: Retrieved related artists for 0G96TkItgnb79cFLnUbdhy
# API call 89: Retrieved artist 5VJPxda81cx3ZGltjWM36I
# API call 90: Retrieved related artists for 5VJPxda81cx3ZGltjWM36I
# API call 91: Retrieved artist 0q74f5UdR3j14Lis4AKKxq
# API call 92: Retrieved related artists for 0q74f5UdR3j14Lis4AKKxq
# API call 93: Retrieved artist 5EWAtvRDy8I6sSYlMjD6g0
# API call 94: Retrieved related artists for 5EWAtvRDy8I6sSYlMjD6g0
# API call 95: Retrieved artist 3BgSkC40Vy5XIcu6MKIYv5
# API call 96: Retrieved related artists for 3BgSkC40Vy5XIcu6MKIYv5
# API call 97: Retrieved artist 22F1oyYmK9AhHbvqzWwsTA
# API call 98: Retrieved related artists for 22F1oyYmK9AhHbvqzWwsTA
# API call 99: Retrieved artist 1P1y4wp6V0CwjhGcXPKgAu
# API call 100: Retrieved related artists for 1P1y4wp6V0CwjhGcXPKgAu
# API call 101: Retrieved artist 2PWXHVDEtObSmUrNhfPRav
# API call 102: Retrieved related artists for 2PWXHVDEtObSmUrNhfPRav
# API call 103: Retrieved artist 0XGJ3GUPwslwFJ66yNbHeh
# API call 104: Retrieved related artists for 0XGJ3GUPwslwFJ66yNbHeh
# API call 105: Retrieved artist 6Xq9CIMYWK4RCrMVtfEOM0
# API call 106: Retrieved related artists for 6Xq9CIMYWK4RCrMVtfEOM0
# API call 107: Retrieved artist 2EIhbnEc2cvYIAsXXbo9tg
# API call 108: Retrieved related artists for 2EIhbnEc2cvYIAsXXbo9tg
# API call 109: Retrieved artist 45V5yoo6fI5r3m7kei0onQ
# API call 110: Retrieved related artists for 45V5yoo6fI5r3m7kei0onQ
# API call 111: Retrieved artist 3LqgxOMfONGBf034jekl9H
# API call 112: Retrieved related artists for 3LqgxOMfONGBf034jekl9H
# API call 113: Retrieved artist 0A5hWmrfSIIExWIb1bsWlo
# API call 114: Retrieved related artists for 0A5hWmrfSIIExWIb1bsWlo
# API call 115: Retrieved artist 2bUBytTbsYzDBKS9oD29Ot
# API call 116: Retrieved related artists for 2bUBytTbsYzDBKS9oD29Ot
# API call 117: Retrieved artist 3Ob2XggbUH1tt9kKh0gX9s
# API call 118: Retrieved related artists for 3Ob2XggbUH1tt9kKh0gX9s
# API call 119: Retrieved artist 5SqEUtwknf60LhsorYoU0Q
# API call 120: Retrieved related artists for 5SqEUtwknf60LhsorYoU0Q
# API call 121: Retrieved artist 0p4HmzIpWq8e3daRrFq8nH
# API call 122: Retrieved related artists for 0p4HmzIpWq8e3daRrFq8nH
# API call 123: Retrieved artist 0NbzkSu0kTo1u5nrKzSkZo
# API call 124: Retrieved related artists for 0NbzkSu0kTo1u5nrKzSkZo
# API call 125: Retrieved artist 5ZU1uyBW2sBqLSm3ep9P9s
# API call 126: Retrieved related artists for 5ZU1uyBW2sBqLSm3ep9P9s
# API call 127: Retrieved artist 5YDv1CXYrDntS7hcka1tsW
# API call 128: Retrieved related artists for 5YDv1CXYrDntS7hcka1tsW
# API call 129: Retrieved artist 4j2I6kcPvgQR4EZY5Wom8K
# API call 130: Retrieved related artists for 4j2I6kcPvgQR4EZY5Wom8K
# API call 131: Retrieved artist 38XtVKjOWfx0lHJ5yzvkAD
# API call 132: Retrieved related artists for 38XtVKjOWfx0lHJ5yzvkAD
# API call 133: Retrieved artist 3AOC9I5ulAaZ6AidcVCUm1
# API call 134: Retrieved related artists for 3AOC9I5ulAaZ6AidcVCUm1
# API call 135: Retrieved artist 5Li751cOM3eHL0nyTg26yS
# API call 136: Retrieved related artists for 5Li751cOM3eHL0nyTg26yS
# API call 137: Retrieved artist 5z1RN8UciVzhQ44jigdItd
# API call 138: Retrieved related artists for 5z1RN8UciVzhQ44jigdItd
# API call 139: Retrieved artist 7hXRirdnjvff6gdmB0Ie2N
# API call 140: Retrieved related artists for 7hXRirdnjvff6gdmB0Ie2N
# API call 141: Retrieved artist 7m4JoKyahi7pjxoffuutnb
# API call 142: Retrieved related artists for 7m4JoKyahi7pjxoffuutnb
# API call 143: Retrieved artist 5RlzblfIoE5f234BZDK6a4
# API call 144: Retrieved related artists for 5RlzblfIoE5f234BZDK6a4
# API call 145: Retrieved artist 2lY409kgxIfLjSv0FBcidK
# API call 146: Retrieved related artists for 2lY409kgxIfLjSv0FBcidK
# API call 147: Retrieved artist 0k8VK8VahrJvwiYTbCU2N2
# API call 148: Retrieved related artists for 0k8VK8VahrJvwiYTbCU2N2
# API call 149: Retrieved artist 6YDZr9xf5q6FZHpEaAS5iM
# API call 150: Retrieved related artists for 6YDZr9xf5q6FZHpEaAS5iM
# API call 151: Retrieved artist 4tfoXU6gBAIS4VlELniyLF
# API call 152: Retrieved related artists for 4tfoXU6gBAIS4VlELniyLF
# API call 153: Retrieved artist 5OAXAvBaZoIU12THZLL5FP
# API call 154: Retrieved related artists for 5OAXAvBaZoIU12THZLL5FP
# API call 155: Retrieved artist 6J0EtgUDcpvWSsWAnjsCCT
# API call 156: Retrieved related artists for 6J0EtgUDcpvWSsWAnjsCCT
# API call 157: Retrieved artist 1jCtTRdAHerWE5H1bayIqb
# API call 158: Retrieved related artists for 1jCtTRdAHerWE5H1bayIqb
# API call 159: Retrieved artist 493q9CX6Jfqz84BMKeE1pT
# API call 160: Retrieved related artists for 493q9CX6Jfqz84BMKeE1pT
# API call 161: Retrieved artist 4MR5biUP26JCpq8QEAkh3z
# API call 162: Retrieved related artists for 4MR5biUP26JCpq8QEAkh3z
# API call 163: Retrieved artist 7bLrwX8HkyBWahu7yvw7bJ
# API call 164: Retrieved related artists for 7bLrwX8HkyBWahu7yvw7bJ
# API call 165: Retrieved artist 4c3N0E0B4sKKWnNY57o4dc
# API call 166: Retrieved related artists for 4c3N0E0B4sKKWnNY57o4dc
# API call 167: Retrieved artist 74Fn06wKcWjnl8b6kNDXS1
# API call 168: Retrieved related artists for 74Fn06wKcWjnl8b6kNDXS1
# API call 169: Retrieved artist 0NGfKXlUtgavM7bHcgwcR6
# API call 170: Retrieved related artists for 0NGfKXlUtgavM7bHcgwcR6
# API call 171: Retrieved artist 0ftqYHMYCnGkoDDh84a9Kr
# API call 172: Retrieved related artists for 0ftqYHMYCnGkoDDh84a9Kr
# API call 173: Retrieved artist 43xDfWXp8dUFvWSs9gamKw
# API call 174: Retrieved related artists for 43xDfWXp8dUFvWSs9gamKw
# API call 175: Retrieved artist 77j2Wg2asSs9MfCOl7qsxr
# API call 176: Retrieved related artists for 77j2Wg2asSs9MfCOl7qsxr
# API call 177: Retrieved artist 2zNLtV3Q59lBarvW1j0Fd1
# API call 178: Retrieved related artists for 2zNLtV3Q59lBarvW1j0Fd1
# API call 179: Retrieved artist 0JLuLGgAw6rAF5fOZiaP3u
# API call 180: Retrieved related artists for 0JLuLGgAw6rAF5fOZiaP3u
# API call 181: Retrieved artist 0R200rkdtVQK8mZVzroOn0
# API call 182: Retrieved related artists for 0R200rkdtVQK8mZVzroOn0
# API call 183: Retrieved artist 3p3uS8OT2Bf4p69e4TBZl0
# API call 184: Retrieved related artists for 3p3uS8OT2Bf4p69e4TBZl0
# API call 185: Retrieved artist 1gzqMaNtHI85YIVvZlcZHe
# API call 186: Retrieved related artists for 1gzqMaNtHI85YIVvZlcZHe
# API call 187: Retrieved artist 4rWiBOZaoxWq2So3DSM0yJ
# API call 188: Retrieved related artists for 4rWiBOZaoxWq2So3DSM0yJ
# API call 189: Retrieved artist 4zTePZKs9vWT8sI09LKaHl
# API call 190: Retrieved related artists for 4zTePZKs9vWT8sI09LKaHl
# API call 191: Retrieved artist 5hY147BcLujpcYM6FtX5LO
# API call 192: Retrieved related artists for 5hY147BcLujpcYM6FtX5LO
# API call 193: Retrieved artist 7lkzEj6pZz8BWsRkLH4VpW
# API call 194: Retrieved related artists for 7lkzEj6pZz8BWsRkLH4VpW
# API call 195: Retrieved artist 5zaZ2lXpIoeE7QWKB8Xlyn
# API call 196: Retrieved related artists for 5zaZ2lXpIoeE7QWKB8Xlyn
# API call 197: Retrieved artist 3bjETx2cWVXnKqMvKMRoaf
# API call 198: Retrieved related artists for 3bjETx2cWVXnKqMvKMRoaf
# API call 199: Retrieved artist 55VgJDsTdSrGZ9aVaa3az8
# API call 200: Retrieved related artists for 55VgJDsTdSrGZ9aVaa3az8
# Total API calls made: 200
# Taylor Swift crawled DFS
# gD degree stats: {'in_degree': {'min': 0, 'max': 33, 'median': 2}, 'out_degree': {'min': 0, 'max': 20, 'median': 0}, 'number_of_nodes': 601, 'number_of_edges': 1995}
# Taylor Swift id: 06HL4z0CvFAxyc27GXpf02
# API call 1: Retrieved artist 06O23tLg0or676h8EEzH7W
# API call 2: Retrieved related artists for 06O23tLg0or676h8EEzH7W
# API call 3: Retrieved artist 48nHO1cuTbpx4ELhChsxX1
# API call 4: Retrieved related artists for 48nHO1cuTbpx4ELhChsxX1
# API call 5: Retrieved artist 7riQPkkGZBnTh9ve5qIhYo
# API call 6: Retrieved related artists for 7riQPkkGZBnTh9ve5qIhYo
# API call 7: Retrieved artist 1wUtnIM66rOLpg70aCDY7f
# API call 8: Retrieved related artists for 1wUtnIM66rOLpg70aCDY7f
# API call 9: Retrieved artist 2jwC7uml6QVgLBfx1Hbtek
# API call 10: Retrieved related artists for 2jwC7uml6QVgLBfx1Hbtek
# API call 11: Retrieved artist 7K3zpFXBvPcvzhj7zlGJdO
# API call 12: Retrieved related artists for 7K3zpFXBvPcvzhj7zlGJdO
# API call 13: Retrieved artist 1ARDx2oCR7sJEjbnHsbbRU
# API call 14: Retrieved related artists for 1ARDx2oCR7sJEjbnHsbbRU
# API call 15: Retrieved artist 4qUoZ6ErhTYFhAI0W1iI9q
# API call 16: Retrieved related artists for 4qUoZ6ErhTYFhAI0W1iI9q
# API call 17: Retrieved artist 0zilOJ2Ze0FLrQ76cZQaoc
# API call 18: Retrieved related artists for 0zilOJ2Ze0FLrQ76cZQaoc
# API call 19: Retrieved artist 0pWwt5vGNzezEhfAcc420Y
# API call 20: Retrieved related artists for 0pWwt5vGNzezEhfAcc420Y
# API call 21: Retrieved artist 6CrThJMQVJfWaHeliiLHuw
# API call 22: Retrieved related artists for 6CrThJMQVJfWaHeliiLHuw
# API call 23: Retrieved artist 3TJZG17pjOKXwx1ELKJPfm
# API call 24: Retrieved related artists for 3TJZG17pjOKXwx1ELKJPfm
# API call 25: Retrieved artist 4ukk0IyB7vL97QirpOcNr3
# API call 26: Retrieved related artists for 4ukk0IyB7vL97QirpOcNr3
# API call 27: Retrieved artist 17Vw9uuOYB7XYjPt0LNFN0
# API call 28: Retrieved related artists for 17Vw9uuOYB7XYjPt0LNFN0
# API call 29: Retrieved artist 0OO76E5lRfeyBI3fkA73Dr
# API call 30: Retrieved related artists for 0OO76E5lRfeyBI3fkA73Dr
# API call 31: Retrieved artist 3XxNRirzbjfLdDli06zMaB
# API call 32: Retrieved related artists for 3XxNRirzbjfLdDli06zMaB
# API call 33: Retrieved artist 0TdyFEXGty3cRKFCI1CJPr
# API call 34: Retrieved related artists for 0TdyFEXGty3cRKFCI1CJPr
# API call 35: Retrieved artist 5AyEXCtu3xnnsTGCo4RVZh
# API call 36: Retrieved related artists for 5AyEXCtu3xnnsTGCo4RVZh
# API call 37: Retrieved artist 6yjz9vY01vOQUcFIAEYVQ0
# API call 38: Retrieved related artists for 6yjz9vY01vOQUcFIAEYVQ0
# API call 39: Retrieved artist 5jTtGLk1mGFMY5lQOvJYUj
# API call 40: Retrieved related artists for 5jTtGLk1mGFMY5lQOvJYUj
# API call 41: Retrieved artist 053q0ukIDRgzwTr4vNSwab
# API call 42: Retrieved related artists for 053q0ukIDRgzwTr4vNSwab
# API call 43: Retrieved artist 688qufssIBfmoD8BJxZD9Q
# API call 44: Retrieved related artists for 688qufssIBfmoD8BJxZD9Q
# API call 45: Retrieved artist 4FzthA7DjutA71z91I1DKX
# API call 46: Retrieved related artists for 4FzthA7DjutA71z91I1DKX
# API call 47: Retrieved artist 64AV09dDdCGBGv11QlGOJN
# API call 48: Retrieved related artists for 64AV09dDdCGBGv11QlGOJN
# API call 49: Retrieved artist 7rSykIe3Og1NMbIV6LOeVx
# API call 50: Retrieved related artists for 7rSykIe3Og1NMbIV6LOeVx
# API call 51: Retrieved artist 540egazqjMY2Lm7NPclRQ2
# API call 52: Retrieved related artists for 540egazqjMY2Lm7NPclRQ2
# API call 53: Retrieved artist 3s001vzLUM01WSssGvHhXA
# API call 54: Retrieved related artists for 3s001vzLUM01WSssGvHhXA
# API call 55: Retrieved artist 2Md4qykZwbsTbHF3MD183Z
# API call 56: Retrieved related artists for 2Md4qykZwbsTbHF3MD183Z
# API call 57: Retrieved artist 2231C2oqgdZQmJ0vh6bNX2
# API call 58: Retrieved related artists for 2231C2oqgdZQmJ0vh6bNX2
# API call 59: Retrieved artist 09CJcG6ndtL82D8x9VxaeT
# API call 60: Retrieved related artists for 09CJcG6ndtL82D8x9VxaeT
# API call 61: Retrieved artist 0jpfFJygOanIxOrI719zY5
# API call 62: Retrieved related artists for 0jpfFJygOanIxOrI719zY5
# API call 63: Retrieved artist 3xYvvJ6tjXyJJdEXBs8qf0
# API call 64: Retrieved related artists for 3xYvvJ6tjXyJJdEXBs8qf0
# API call 65: Retrieved artist 6w8h2uD28BEdg7bX4k3Lh7
# API call 66: Retrieved related artists for 6w8h2uD28BEdg7bX4k3Lh7
# API call 67: Retrieved artist 7wxXs62y8Gjf6c6pxrnWIl
# API call 68: Retrieved related artists for 7wxXs62y8Gjf6c6pxrnWIl
# API call 69: Retrieved artist 62s5q1tm3UAcRnbGY9CCI9
# API call 70: Retrieved related artists for 62s5q1tm3UAcRnbGY9CCI9
# API call 71: Retrieved artist 1nVq0hKIVReeaiB3xJgKf0
# API call 72: Retrieved related artists for 1nVq0hKIVReeaiB3xJgKf0
# API call 73: Retrieved artist 6urohrV2xk0fQGPknaw7dx
# API call 74: Retrieved related artists for 6urohrV2xk0fQGPknaw7dx
# API call 75: Retrieved artist 75vqTLIltGApfI0NxcsJaC
# API call 76: Retrieved related artists for 75vqTLIltGApfI0NxcsJaC
# API call 77: Retrieved artist 4iom7VVRU6AHRIu1JUXpLG
# API call 78: Retrieved related artists for 4iom7VVRU6AHRIu1JUXpLG
# API call 79: Retrieved artist 3HSpbkijRqVAa1bn0hyEfz
# API call 80: Retrieved related artists for 3HSpbkijRqVAa1bn0hyEfz
# API call 81: Retrieved artist 0XfguwtX2k7wn8cJvkdjT9
# API call 82: Retrieved related artists for 0XfguwtX2k7wn8cJvkdjT9
# API call 83: Retrieved artist 6TNu2GG0r5FZXtSvdGcLsY
# API call 84: Retrieved related artists for 6TNu2GG0r5FZXtSvdGcLsY
# API call 85: Retrieved artist 2E701AAAlg7LthbISEZv0N
# API call 86: Retrieved related artists for 2E701AAAlg7LthbISEZv0N
# API call 87: Retrieved artist 7kDbLquCet7fR3Mq7JEPUp
# API call 88: Retrieved related artists for 7kDbLquCet7fR3Mq7JEPUp
# API call 89: Retrieved artist 1dK4UZ6zuHSPzkWpCCQEIL
# API call 90: Retrieved related artists for 1dK4UZ6zuHSPzkWpCCQEIL
# API call 91: Retrieved artist 3QMquHHgjA58upVZerNHNx
# API call 92: Retrieved related artists for 3QMquHHgjA58upVZerNHNx
# API call 93: Retrieved artist 3EGYR0O3mIjTxQsVMXTSwO
# API call 94: Retrieved related artists for 3EGYR0O3mIjTxQsVMXTSwO
# API call 95: Retrieved artist 4IfApBEW6RQ9uogE7cuZnJ
# API call 96: Retrieved related artists for 4IfApBEW6RQ9uogE7cuZnJ
# API call 97: Retrieved artist 10m6Fvz501byHhoObkMPVy
# API call 98: Retrieved related artists for 10m6Fvz501byHhoObkMPVy
# API call 99: Retrieved artist 44vCSKVEePe8jkoLBTmGwO
# API call 100: Retrieved related artists for 44vCSKVEePe8jkoLBTmGwO
# API call 101: Retrieved artist 0LWHFUzXPTl9BDdJHDE001
# API call 102: Retrieved related artists for 0LWHFUzXPTl9BDdJHDE001
# API call 103: Retrieved artist 3pFSlKAoVnaEycgIcPDctw
# API call 104: Retrieved related artists for 3pFSlKAoVnaEycgIcPDctw
# API call 105: Retrieved artist 3VNzWLePg9jTvQ2ximYOzW
# API call 106: Retrieved related artists for 3VNzWLePg9jTvQ2ximYOzW
# API call 107: Retrieved artist 75UKUI7fd2RjNRgy8oaNdt
# API call 108: Retrieved related artists for 75UKUI7fd2RjNRgy8oaNdt
# API call 109: Retrieved artist 02vrwnrNEeDRV96o9iPSYP
# API call 110: Retrieved related artists for 02vrwnrNEeDRV96o9iPSYP
# API call 111: Retrieved artist 0qZyvjwZauLmrobrpJmvib
# API call 112: Retrieved related artists for 0qZyvjwZauLmrobrpJmvib
# API call 113: Retrieved artist 0pg0Zm8FsGAYy5kdHuBnSo
# API call 114: Retrieved related artists for 0pg0Zm8FsGAYy5kdHuBnSo
# API call 115: Retrieved artist 1AbJ2cmwK400LSvdvBL5Jc
# API call 116: Retrieved related artists for 1AbJ2cmwK400LSvdvBL5Jc
# API call 117: Retrieved artist 1jsT4oqnLcCax2grWbuhL6
# API call 118: Retrieved related artists for 1jsT4oqnLcCax2grWbuhL6
# API call 119: Retrieved artist 2HpfqDQ8DBQlnrbAsdIh7s
# API call 120: Retrieved related artists for 2HpfqDQ8DBQlnrbAsdIh7s
# API call 121: Retrieved artist 0m5FakHKCQdA7UN0PIzMcL
# API call 122: Retrieved related artists for 0m5FakHKCQdA7UN0PIzMcL
# API call 123: Retrieved artist 0bC6e2YtIRLbKx2txHFmEo
# API call 124: Retrieved related artists for 0bC6e2YtIRLbKx2txHFmEo
# API call 125: Retrieved artist 1tnjjbgszXYa8BbyTzwM0w
# API call 126: Retrieved related artists for 1tnjjbgszXYa8BbyTzwM0w
# API call 127: Retrieved artist 3JDZy6EWo6V8yABANunf6V
# API call 128: Retrieved related artists for 3JDZy6EWo6V8yABANunf6V
# API call 129: Retrieved artist 6kBDZFXuLrZgHnvmPu9NsG
# API call 130: Retrieved related artists for 6kBDZFXuLrZgHnvmPu9NsG
# API call 131: Retrieved artist 6lcwlkAjBPSKnFBZjjZFJs
# API call 132: Retrieved related artists for 6lcwlkAjBPSKnFBZjjZFJs
# API call 133: Retrieved artist 72X6FHxaShda0XeQw3vbeF
# API call 134: Retrieved related artists for 72X6FHxaShda0XeQw3vbeF
# API call 135: Retrieved artist 3G3Gdm0ZRAOxLrbyjfhii5
# API call 136: Retrieved related artists for 3G3Gdm0ZRAOxLrbyjfhii5
# API call 137: Retrieved artist 6Ghvu1VvMGScGpOUJBAHNH
# API call 138: Retrieved related artists for 6Ghvu1VvMGScGpOUJBAHNH
# API call 139: Retrieved artist 0Z7dYQpd2WCyp6UEXFWZ2c
# API call 140: Retrieved related artists for 0Z7dYQpd2WCyp6UEXFWZ2c
# API call 141: Retrieved artist 1f5Qv25dd6ldcXS9aKqDTi
# API call 142: Retrieved related artists for 1f5Qv25dd6ldcXS9aKqDTi
# API call 143: Retrieved artist 2EsL7l54h5MZm34uFVsRQi
# API call 144: Retrieved related artists for 2EsL7l54h5MZm34uFVsRQi
# API call 145: Retrieved artist 5gfMeHMtCy7G8rmCexG7hb
# API call 146: Retrieved related artists for 5gfMeHMtCy7G8rmCexG7hb
# API call 147: Retrieved artist 75xNYf2GU5wtQqBrd74SlY
# API call 148: Retrieved related artists for 75xNYf2GU5wtQqBrd74SlY
# API call 149: Retrieved artist 1ld3NT4hubdY5jvc3r7ZD8
# API call 150: Retrieved related artists for 1ld3NT4hubdY5jvc3r7ZD8
# API call 151: Retrieved artist 3jIi2szsFwzmJCtETr5SaH
# API call 152: Retrieved related artists for 3jIi2szsFwzmJCtETr5SaH
# API call 153: Retrieved artist 40lgCyfmz6zJKM0Ab2dHFi
# API call 154: Retrieved related artists for 40lgCyfmz6zJKM0Ab2dHFi
# API call 155: Retrieved artist 5fxQR7CJ00Cq02ToHNOS0c
# API call 156: Retrieved related artists for 5fxQR7CJ00Cq02ToHNOS0c
# API call 157: Retrieved artist 1CbA4z6JauNQnHzOErDQL6
# API call 158: Retrieved related artists for 1CbA4z6JauNQnHzOErDQL6
# API call 159: Retrieved artist 6qW2MCeqjNlMwiLl0JPbuZ
# API call 160: Retrieved related artists for 6qW2MCeqjNlMwiLl0JPbuZ
# API call 161: Retrieved artist 31ijgiurmIPTNojkYQXdnl
# API call 162: Retrieved related artists for 31ijgiurmIPTNojkYQXdnl
# API call 163: Retrieved artist 3sklFG9fuDAq3vbIZlkNH6
# API call 164: Retrieved related artists for 3sklFG9fuDAq3vbIZlkNH6
# API call 165: Retrieved artist 08ZqXO40nMrhBoGma4kls2
# API call 166: Retrieved related artists for 08ZqXO40nMrhBoGma4kls2
# API call 167: Retrieved artist 7GcVOOrldYLwxGrCkELOno
# API call 168: Retrieved related artists for 7GcVOOrldYLwxGrCkELOno
# API call 169: Retrieved artist 700c9Qz2z6HZKTumeliKAw
# API call 170: Retrieved related artists for 700c9Qz2z6HZKTumeliKAw
# API call 171: Retrieved artist 31wcwYyqQIfZCtIzCY3R53
# API call 172: Retrieved related artists for 31wcwYyqQIfZCtIzCY3R53
# API call 173: Retrieved artist 7yH0tCtttU4pORkXn6rWZS
# API call 174: Retrieved related artists for 7yH0tCtttU4pORkXn6rWZS
# API call 175: Retrieved artist 3UxUktdCJsomjKqozWDWSu
# API call 176: Retrieved related artists for 3UxUktdCJsomjKqozWDWSu
# API call 177: Retrieved artist 6hKH8NJ9tDDqDEOWtiUntb
# API call 178: Retrieved related artists for 6hKH8NJ9tDDqDEOWtiUntb
# API call 179: Retrieved artist 1WtnKgt4QpM8eNxWN4H7cY
# API call 180: Retrieved related artists for 1WtnKgt4QpM8eNxWN4H7cY
# API call 181: Retrieved artist 5g97nXsHBZDyY6wPKckqLc
# API call 182: Retrieved related artists for 5g97nXsHBZDyY6wPKckqLc
# API call 183: Retrieved artist 4xNuIo74R6m1eXaz7RlpZ6
# API call 184: Retrieved related artists for 4xNuIo74R6m1eXaz7RlpZ6
# API call 185: Retrieved artist 1rPMCfJhANfBT78l2wf4d6
# API call 186: Retrieved related artists for 1rPMCfJhANfBT78l2wf4d6
# API call 187: Retrieved artist 4RsEAdLhbUy7j3zHWauPwF
# API call 188: Retrieved related artists for 4RsEAdLhbUy7j3zHWauPwF
# API call 189: Retrieved artist 7643SmlrrhFGpLMgSJnvxd
# API call 190: Retrieved related artists for 7643SmlrrhFGpLMgSJnvxd
# API call 191: Retrieved artist 3XCfdFic107Iv8zMzyRTJt
# API call 192: Retrieved related artists for 3XCfdFic107Iv8zMzyRTJt
# API call 193: Retrieved artist 61TQfpvTjHYQjPrvtJPwVa
# API call 194: Retrieved related artists for 61TQfpvTjHYQjPrvtJPwVa
# API call 195: Retrieved artist 0bb1EZkY7SlcGKU9e5T9DL
# API call 196: Retrieved related artists for 0bb1EZkY7SlcGKU9e5T9DL
# API call 197: Retrieved artist 32ENZVmItiETXMCYfM1bbS
# API call 198: Retrieved related artists for 32ENZVmItiETXMCYfM1bbS
# API call 199: Retrieved artist 14xRX3JR8H4RWh8R7V3fvZ
# API call 200: Retrieved related artists for 14xRX3JR8H4RWh8R7V3fvZ
# Total API calls made: 200
# Pastel Ghost crawled BFS
# hB degree stats: {'in_degree': {'min': 1, 'max': 22, 'median': 1}, 'out_degree': {'min': 0, 'max': 20, 'median': 0}, 'number_of_nodes': 764, 'number_of_edges': 1995}

# %%
"""# Spotify API credentials
CLIENT_ID = "a96a3af9660440769efb49b1785fd7b2"
CLIENT_SECRET = "2e50c0969ed44cd0a254ad301de00f50"

auth_manager = SpotifyClientCredentials(
    client_id=CLIENT_ID,
    client_secret=CLIENT_SECRET
)

sp = spotipy.Spotify(auth_manager=auth_manager)
"""
# Read the graphs
Gb = nx.read_graphml("gB.graphml")
Gd = nx.read_graphml("gD.graphml")

# Intersect the graphs
G_intersection = nx.intersection(Gb, Gd)
print(f"Number of nodes in the intersection: {G_intersection.number_of_nodes()}")
print(f"Number of edges in the intersection: {G_intersection.number_of_edges()}")


# Track data
D = get_track_data(sp, G_intersection, "songs.csv")

# Summary statistics
num_songs = D['track_id'].nunique()
num_artists = D['artist_id'].nunique()
num_albums = D['album_id'].nunique()

print(f"Artists: {num_artists}")
print(f"Albums: {num_albums}")
print(f"Songs: {num_songs}")
# Out:
# Number of nodes in the intersection: 138
# Number of edges in the intersection: 140
# Batch 1 processed. Waiting for 10 seconds...
# Batch 2 processed. Waiting for 10 seconds...
# Batch 3 processed. Waiting for 10 seconds...
# Batch 4 processed. Waiting for 10 seconds...
# Batch 5 processed. Waiting for 10 seconds...
# Artists: 138
# Albums: 733
# Songs: 1269
